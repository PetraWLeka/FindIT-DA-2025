# %% [markdown]
# # Data processing

# %%
import pandas as pd

# %%
# -------------------------------
# 1. Load the data
# -------------------------------
train_df = pd.read_csv(r"E:\project\MLComp\FindIT\2025\data\train.csv")
target_df = pd.read_csv(r"E:\project\MLComp\FindIT\2025\data\target.csv")
test_df = pd.read_csv(r"E:\project\MLComp\FindIT\2025\data\test.csv")
submission_format = pd.read_csv(r"E:\project\MLComp\FindIT\2025\data\submission_format.csv")
# Concatenate train and target as they are already in order.
train_df["coppaRisk"] = target_df["coppaRisk"]

# -------------------------------
# 2. New Missing‐Value and Flag Features
# -------------------------------

# 2.1 countryCode: treat NaN as its own category 'nan'
for df in [train_df, test_df]:
    df["countryCode"] = df["countryCode"].fillna("nan")  # fill missing categoricals with 'nan' :contentReference[oaicite:0]{index=0}

# 2.2 downloads → Downloads_avg: parse ranges; if downloads is NaN, set Downloads_avg = 0
def parse_downloads(x):
    if pd.isna(x):
        return 0.0  # missing downloads → zero average :contentReference[oaicite:1]{index=1}
    parts = x.split('-')
    if len(parts)==2:
        return (float(parts[0].strip()) + float(parts[1].strip())) / 2.0
    return np.nan

for df in [train_df, test_df]:
    if 'downloads' in df.columns:
        df["Downloads_avg"] = df["downloads"].apply(parse_downloads)

# 2.3 hasTermsOfServiceLink & hasTermsOfServiceLinkRating: missing → new category 'None'
for df in [train_df, test_df]:
    df[["hasTermsOfServiceLink", "hasTermsOfServiceLinkRating"]] = \
        df[["hasTermsOfServiceLink", "hasTermsOfServiceLinkRating"]].fillna("None")  # new category :contentReference[oaicite:2]{index=2}

# 2.4 adSpent: flag missingness and replace missing with -1
for df in [train_df, test_df]:
    df["adSpend_isna"] = df["adSpent"].isna().astype(int)  # 1 if missing, 0 otherwise :contentReference[oaicite:3]{index=3}
    df["adSpent"] = df["adSpent"].fillna(-1)               # missing adSpent → -1 :contentReference[oaicite:4]{index=4}

# 2.5 averageUserRating must be integer 0–5
# for df in [train_df, test_df]:
#     df["averageUserRating"] = df["averageUserRating"].round().astype(int)
#     df["averageUserRating"] = np.clip(df["averageUserRating"], 0, 5)  # ensure within [0,5] :contentReference[oaicite:5]{index=5}

# 2.6 appContentBrandSafetyRating: treat NaN as its own category 'nan'
for df in [train_df, test_df]:
    df["appContentBrandSafetyRating"] = df["appContentBrandSafetyRating"].fillna("nan")  # new category :contentReference[oaicite:6]{index=6}

# -------------------------------
# 3. Data Cleaning Functions
# -------------------------------
def clean_developer_country(df):
    mask = df["developerCountry"].isin([
        "ADDRESS NOT LISTED IN PLAYSTORE",
        "CANNOT IDENTIFY COUNTRY",
        "PERSONAL DATA, CAN NOT BE PUBLICLY DISCLOSED ACCORDING TO APPLICABLE LAWS.",
        "STATUTORY MASKING ENABLED"
    ])
    df.loc[mask, "developerCountry"] = "Empty"
    return df

train_df = clean_developer_country(train_df)
test_df = clean_developer_country(test_df)

# -------------------------------
# 4. Define Feature Groups
# -------------------------------
numerical_cols = [
    'userRatingCount', 'isCorporateEmailScore', 'adSpent',
    'appAge', 'averageUserRating', 'Downloads_avg'
]
binary_cols = ['hasPrivacyLink', 'hasTermsOfServiceLink']
nominal_cols = [
    'developerCountry', 'countryCode', 'primaryGenreName',
    'deviceType', 'appContentBrandSafetyRating'
]
ordinal_cols = [
    'hasTermsOfServiceLinkRating',
    'appDescriptionBrandSafetyRating',
    'mfaRating'
]
ordinal_mapping = {'low': 1, 'medium': 2, 'high': 3}

# -------------------------------
# 5. Imputation Functions
# -------------------------------
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import KNNImputer, IterativeImputer
from sklearn.preprocessing import OrdinalEncoder

def impute_nominal_knn(df, columns):
    temp = df[columns].replace("", np.nan).copy()
    encoder = OrdinalEncoder(
        handle_unknown="use_encoded_value", unknown_value=-1
    )
    encoded = encoder.fit_transform(temp)
    imputed = KNNImputer(n_neighbors=5).fit_transform(encoded)  # KNN imputation :contentReference[oaicite:7]{index=7}
    decoded = encoder.inverse_transform(np.round(imputed).astype(int))
    df[columns] = decoded
    return df

def impute_ordinal_numerical_iter(df, columns):
    df_num = df[columns].replace("", np.nan).astype(float)
    df[columns] = IterativeImputer(random_state=42).fit_transform(df_num)  # MICE imputation :contentReference[oaicite:8]{index=8}
    return df
# -------------------------------
# 6. Preprocess the datasets
# -------------------------------
def preprocess_df(df):
    # df = impute_nominal_knn(df, nominal_cols)  # fill nominal categoricals
    for col in ordinal_cols:
        df[col] = df[col].map(ordinal_mapping)
    impute_cols = ordinal_cols + numerical_cols
    # df = impute_ordinal_numerical_iter(df, impute_cols)
    # for col in ordinal_cols:
    #     df[col] = np.round(df[col]).astype(int)
    # One-hot encode nominal columns (now including appContentBrandSafetyRating)
    from sklearn.preprocessing import OneHotEncoder
    df = pd.get_dummies(df, columns=nominal_cols, drop_first=True)  # OHE :contentReference[oaicite:9]{index=9}
    for col in binary_cols + ['adSpend_isna']:
        df[col] = df[col].apply(lambda x: 1 if str(x).lower() in ["true", "1"] else 0)
    return df

train_processed = preprocess_df(train_df.copy())
test_processed  = preprocess_df(test_df.copy())
# 7. Final Alignment and Split
# -------------------------------
train_features = train_processed.drop(['coppaRisk', 'downloads'], axis=1, errors='ignore')
y = (train_processed['coppaRisk'].astype(str).str.lower() == 'true').astype(int)
test_features = test_processed.reindex(columns=train_features.columns, fill_value=0)

# Clean column names
import re
train_features.columns = train_features.columns.map(lambda x: re.sub(r'[^A-Za-z0-9_]+', '', x))
test_features.columns  = test_features.columns.map(lambda x: re.sub(r'[^A-Za-z0-9_]+', '', x))

# Stratified split
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(
    train_features, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# # Only catboost

# %%
import numpy as np
import optuna
from catboost import CatBoostClassifier
from sklearn.metrics import roc_auc_score

# Configuration
N_MODELS = 9
SEED     = 42
ROUNDS   = 300   # you can adjust

# Make sure you’ve already done:
# from sklearn.model_selection import train_test_split
# X_train, X_val, y_train, y_val = train_test_split( ... stratify=y ... )

def objective(trial):
    # 1) sample hyperparameters
    params = {
        'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
        'depth':              trial.suggest_int('depth', 4, 10),
        'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
        'min_data_in_leaf':   trial.suggest_int('min_data_in_leaf', 5, 100),
        'border_count':       trial.suggest_int('border_count', 32, 255),
        'random_strength':    trial.suggest_float('random_strength', 0.0, 1.0),
        'subsample':          trial.suggest_float('subsample', 0.4, 1.0),
        'rsm':                trial.suggest_float('rsm', 0.4, 1.0),
        'bootstrap_type':     'Bernoulli',            # supports subsample on CPU
        'objective':          'Logloss',
        'eval_metric':        'AUC',
        'verbose':            False,
        'random_seed':        SEED,
        'task_type':          'CPU'
    }

    # 2) majority/minority splits on X_train
    arr = y_train.values
    maj_idx = np.where(arr == 0)[0]
    rar_idx = np.where(arr == 1)[0]
    rng = np.random.RandomState(SEED)
    splits = np.array_split(rng.permutation(maj_idx), N_MODELS)

    # 3) train an ensemble on X_train → predict on X_val
    preds = np.zeros(len(X_val), dtype=float)
    for grp in splits:
        idx = np.sort(np.concatenate([rar_idx, grp]))
        X_sub, y_sub = X_train.iloc[idx], y_train.iloc[idx]
        m = CatBoostClassifier(**params, iterations=ROUNDS)
        m.fit(X_sub, y_sub)
        preds += m.predict_proba(X_val)[:, 1]
    preds /= N_MODELS

    return roc_auc_score(y_val, preds)

# run Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100, timeout=6000)

print("▶ Best CatBoost parameters:")
for k, v in study.best_trial.params.items():
    print(f"   {k}: {v}")
print(f"▶ Best hold-out AUC: {study.best_value:.4f}")
# Out:
# [I 2025-04-28 08:20:21,378] A new study created in memory with name: no-name-95e1939e-2c41-467f-9d2e-e4004d73fd8a
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:20:26,441] Trial 0 finished with value: 0.8944539847899635 and parameters: {'learning_rate': 0.006255888445794001, 'depth': 4, 'l2_leaf_reg': 1.1164171204811146, 'min_data_in_leaf': 48, 'border_count': 186, 'random_strength': 0.3127155827025371, 'subsample': 0.4780949240439404, 'rsm': 0.765934571418941}. Best is trial 0 with value: 0.8944539847899635.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:20:33,912] Trial 1 finished with value: 0.8990067264190233 and parameters: {'learning_rate': 0.00897724153139161, 'depth': 7, 'l2_leaf_reg': 0.24567385068743638, 'min_data_in_leaf': 29, 'border_count': 132, 'random_strength': 0.5797406719128688, 'subsample': 0.47933850515635534, 'rsm': 0.8844700324564194}. Best is trial 1 with value: 0.8990067264190233.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:20:38,300] Trial 2 finished with value: 0.897466325115958 and parameters: {'learning_rate': 0.056455544523767304, 'depth': 4, 'l2_leaf_reg': 1.6415081499908337, 'min_data_in_leaf': 59, 'border_count': 121, 'random_strength': 0.1324265787979323, 'subsample': 0.8318447157394696, 'rsm': 0.4339523192382513}. Best is trial 1 with value: 0.8990067264190233.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:20:48,434] Trial 3 finished with value: 0.8931646118473976 and parameters: {'learning_rate': 0.005953338919576716, 'depth': 8, 'l2_leaf_reg': 4.6221893127743445e-08, 'min_data_in_leaf': 61, 'border_count': 78, 'random_strength': 0.10236812789999072, 'subsample': 0.515850384156908, 'rsm': 0.588304972737362}. Best is trial 1 with value: 0.8990067264190233.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:20:57,205] Trial 4 finished with value: 0.8905687503922319 and parameters: {'learning_rate': 0.0015894076640586405, 'depth': 7, 'l2_leaf_reg': 5.7925969669785485e-08, 'min_data_in_leaf': 82, 'border_count': 207, 'random_strength': 0.7302579041532224, 'subsample': 0.40966152683049734, 'rsm': 0.9383120858636929}. Best is trial 1 with value: 0.8990067264190233.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:21:04,153] Trial 5 finished with value: 0.8997769270705561 and parameters: {'learning_rate': 0.012769801076603837, 'depth': 7, 'l2_leaf_reg': 2.0931633367208664e-07, 'min_data_in_leaf': 60, 'border_count': 66, 'random_strength': 0.6721939587656186, 'subsample': 0.49744883265706497, 'rsm': 0.9271199335790925}. Best is trial 5 with value: 0.8997769270705561.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:21:38,600] Trial 6 finished with value: 0.8991892924993866 and parameters: {'learning_rate': 0.007340483446631275, 'depth': 10, 'l2_leaf_reg': 0.008744851477065335, 'min_data_in_leaf': 53, 'border_count': 237, 'random_strength': 0.6604201593403125, 'subsample': 0.6657739350815814, 'rsm': 0.7770677983272425}. Best is trial 5 with value: 0.8997769270705561.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:21:44,035] Trial 7 finished with value: 0.8960970795132331 and parameters: {'learning_rate': 0.004989014656752858, 'depth': 5, 'l2_leaf_reg': 0.008393849166538203, 'min_data_in_leaf': 6, 'border_count': 49, 'random_strength': 0.9056031677835439, 'subsample': 0.6964503760297025, 'rsm': 0.4560792778817566}. Best is trial 5 with value: 0.8997769270705561.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:22:11,395] Trial 8 finished with value: 0.9004444343018844 and parameters: {'learning_rate': 0.029973617170161556, 'depth': 10, 'l2_leaf_reg': 0.12316739524033865, 'min_data_in_leaf': 76, 'border_count': 182, 'random_strength': 0.8357184436816864, 'subsample': 0.6088349989299702, 'rsm': 0.5447007727498071}. Best is trial 8 with value: 0.9004444343018844.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:22:18,651] Trial 9 finished with value: 0.8975918392962077 and parameters: {'learning_rate': 0.027408954120210216, 'depth': 7, 'l2_leaf_reg': 0.23562326772256684, 'min_data_in_leaf': 5, 'border_count': 64, 'random_strength': 0.07049452722384897, 'subsample': 0.9293238737823403, 'rsm': 0.6284095383327506}. Best is trial 8 with value: 0.9004444343018844.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:22:46,137] Trial 10 finished with value: 0.8850917679813325 and parameters: {'learning_rate': 0.0932813231163474, 'depth': 10, 'l2_leaf_reg': 1.6599054590418596e-05, 'min_data_in_leaf': 98, 'border_count': 170, 'random_strength': 0.961656325239869, 'subsample': 0.6439064214672445, 'rsm': 0.5539303102914949}. Best is trial 8 with value: 0.9004444343018844.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:23:00,135] Trial 11 finished with value: 0.8968672801647658 and parameters: {'learning_rate': 0.0231894526297818, 'depth': 9, 'l2_leaf_reg': 1.8981826609781756e-05, 'min_data_in_leaf': 78, 'border_count': 95, 'random_strength': 0.7921738625263383, 'subsample': 0.5832223261659165, 'rsm': 0.6920405569844745}. Best is trial 8 with value: 0.9004444343018844.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:23:07,077] Trial 12 finished with value: 0.8978029313266279 and parameters: {'learning_rate': 0.019664398628943144, 'depth': 6, 'l2_leaf_reg': 2.4859436359321345e-06, 'min_data_in_leaf': 77, 'border_count': 156, 'random_strength': 0.43886529083668435, 'subsample': 0.7638869022176935, 'rsm': 0.8241034446174893}. Best is trial 8 with value: 0.9004444343018844.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:23:25,392] Trial 13 finished with value: 0.8924856942360465 and parameters: {'learning_rate': 0.04236529844491976, 'depth': 9, 'l2_leaf_reg': 0.002451663114422388, 'min_data_in_leaf': 39, 'border_count': 253, 'random_strength': 0.46625457056911507, 'subsample': 0.5610622398278585, 'rsm': 0.950742723511546}. Best is trial 8 with value: 0.9004444343018844.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:23:35,356] Trial 14 finished with value: 0.9015626515441097 and parameters: {'learning_rate': 0.015870912469982998, 'depth': 8, 'l2_leaf_reg': 0.00025488508996961617, 'min_data_in_leaf': 99, 'border_count': 100, 'random_strength': 0.8138863325037569, 'subsample': 0.41041348612582973, 'rsm': 0.535300107702936}. Best is trial 14 with value: 0.9015626515441097.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:23:50,908] Trial 15 finished with value: 0.8943627017497818 and parameters: {'learning_rate': 0.0023983185690472694, 'depth': 9, 'l2_leaf_reg': 0.0004071950932506022, 'min_data_in_leaf': 97, 'border_count': 108, 'random_strength': 0.8613318193461155, 'subsample': 0.7928559722435743, 'rsm': 0.4947677093976459}. Best is trial 14 with value: 0.9015626515441097.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:24:02,112] Trial 16 finished with value: 0.9005642432921229 and parameters: {'learning_rate': 0.016074383778188, 'depth': 8, 'l2_leaf_reg': 0.04349643112266632, 'min_data_in_leaf': 89, 'border_count': 205, 'random_strength': 0.9999544877529574, 'subsample': 0.40033279820847667, 'rsm': 0.5214905187570255}. Best is trial 14 with value: 0.9015626515441097.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:24:13,107] Trial 17 finished with value: 0.8994574364299203 and parameters: {'learning_rate': 0.014202909084398307, 'depth': 8, 'l2_leaf_reg': 0.000272202191916828, 'min_data_in_leaf': 90, 'border_count': 210, 'random_strength': 0.9832259659923684, 'subsample': 0.4026068282415718, 'rsm': 0.6563101270370599}. Best is trial 14 with value: 0.9015626515441097.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:24:21,882] Trial 18 finished with value: 0.8970555514351406 and parameters: {'learning_rate': 0.003706550985281814, 'depth': 8, 'l2_leaf_reg': 6.733104520308909, 'min_data_in_leaf': 88, 'border_count': 33, 'random_strength': 0.2992919872526026, 'subsample': 0.42877094461737436, 'rsm': 0.40226411556470726}. Best is trial 14 with value: 0.9015626515441097.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:24:28,593] Trial 19 finished with value: 0.9018193850946206 and parameters: {'learning_rate': 0.014448942040196179, 'depth': 6, 'l2_leaf_reg': 0.00023523281372136618, 'min_data_in_leaf': 70, 'border_count': 145, 'random_strength': 0.9971403385745997, 'subsample': 0.9494471851747835, 'rsm': 0.5018339223497836}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:24:34,948] Trial 20 finished with value: 0.895965860142972 and parameters: {'learning_rate': 0.04920406030197724, 'depth': 6, 'l2_leaf_reg': 0.00014235068210552337, 'min_data_in_leaf': 72, 'border_count': 148, 'random_strength': 0.7519868919362029, 'subsample': 0.998995316259112, 'rsm': 0.6127374775313317}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:24:40,989] Trial 21 finished with value: 0.8992121132594322 and parameters: {'learning_rate': 0.014605962979952727, 'depth': 6, 'l2_leaf_reg': 0.0026835596096856256, 'min_data_in_leaf': 89, 'border_count': 99, 'random_strength': 0.9587748983308239, 'subsample': 0.8832484453744882, 'rsm': 0.5029345569538153}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:24:53,773] Trial 22 finished with value: 0.9000678917611351 and parameters: {'learning_rate': 0.010292167770416815, 'depth': 8, 'l2_leaf_reg': 3.413763685514629e-05, 'min_data_in_leaf': 100, 'border_count': 208, 'random_strength': 0.8949603196798783, 'subsample': 0.7355252011050453, 'rsm': 0.499861893345217}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:24:59,601] Trial 23 finished with value: 0.9002846889815665 and parameters: {'learning_rate': 0.01780433313006277, 'depth': 5, 'l2_leaf_reg': 3.074473965792134e-06, 'min_data_in_leaf': 65, 'border_count': 128, 'random_strength': 0.9720684516493721, 'subsample': 0.9964083963090551, 'rsm': 0.5602373368712477}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:25:04,631] Trial 24 finished with value: 0.8996400025102835 and parameters: {'learning_rate': 0.03436836747113139, 'depth': 5, 'l2_leaf_reg': 0.04051434997029161, 'min_data_in_leaf': 86, 'border_count': 161, 'random_strength': 0.8324751650970863, 'subsample': 0.4494272245337062, 'rsm': 0.45721057502067014}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:25:21,330] Trial 25 finished with value: 0.897466325115958 and parameters: {'learning_rate': 0.0038216570903621583, 'depth': 9, 'l2_leaf_reg': 0.0010394574326608615, 'min_data_in_leaf': 70, 'border_count': 229, 'random_strength': 0.8908612508226047, 'subsample': 0.518662035515782, 'rsm': 0.6764874364785937}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:25:27,257] Trial 26 finished with value: 0.8992292288294662 and parameters: {'learning_rate': 0.011024735085230861, 'depth': 6, 'l2_leaf_reg': 0.020295296548221507, 'min_data_in_leaf': 92, 'border_count': 83, 'random_strength': 0.5562646714275356, 'subsample': 0.8617067873666575, 'rsm': 0.5231523268021027}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:25:36,311] Trial 27 finished with value: 0.8901865026614713 and parameters: {'learning_rate': 0.06762615065034958, 'depth': 8, 'l2_leaf_reg': 0.0001034260804759872, 'min_data_in_leaf': 84, 'border_count': 109, 'random_strength': 0.9952453735708091, 'subsample': 0.5383300092552129, 'rsm': 0.4098050103537133}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:25:43,848] Trial 28 finished with value: 0.9010206584930311 and parameters: {'learning_rate': 0.01921135025285897, 'depth': 7, 'l2_leaf_reg': 0.0013167403111079817, 'min_data_in_leaf': 69, 'border_count': 138, 'random_strength': 0.68548321387307, 'subsample': 0.9134512061944415, 'rsm': 0.7320088237350173}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:25:48,634] Trial 29 finished with value: 0.8966447777543229 and parameters: {'learning_rate': 0.022356119497029606, 'depth': 4, 'l2_leaf_reg': 3.629584385886934e-06, 'min_data_in_leaf': 48, 'border_count': 143, 'random_strength': 0.6523987366790074, 'subsample': 0.9475879521255907, 'rsm': 0.7189701456959928}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:25:55,294] Trial 30 finished with value: 0.899856799730715 and parameters: {'learning_rate': 0.00799786160842828, 'depth': 6, 'l2_leaf_reg': 0.0010210005023286197, 'min_data_in_leaf': 42, 'border_count': 184, 'random_strength': 0.7435571168109012, 'subsample': 0.9389211994272412, 'rsm': 0.7485864926214603}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:26:02,461] Trial 31 finished with value: 0.8983734503277632 and parameters: {'learning_rate': 0.016515824680611094, 'depth': 7, 'l2_leaf_reg': 0.004386381125349427, 'min_data_in_leaf': 68, 'border_count': 119, 'random_strength': 0.9133297531037856, 'subsample': 0.8942784994505156, 'rsm': 0.813315059740882}. Best is trial 19 with value: 0.9018193850946206.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:26:09,953] Trial 32 finished with value: 0.9032171566474021 and parameters: {'learning_rate': 0.03688688094534395, 'depth': 7, 'l2_leaf_reg': 0.06202998934307267, 'min_data_in_leaf': 93, 'border_count': 141, 'random_strength': 0.8195253675619897, 'subsample': 0.46528052286516963, 'rsm': 0.5808697982329277}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:26:17,379] Trial 33 finished with value: 0.8981395375372977 and parameters: {'learning_rate': 0.03697581842986168, 'depth': 7, 'l2_leaf_reg': 3.835999901671309e-05, 'min_data_in_leaf': 27, 'border_count': 138, 'random_strength': 0.7993403369419021, 'subsample': 0.45698992752592316, 'rsm': 0.5893106658823899}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:26:25,043] Trial 34 finished with value: 0.9011005311531901 and parameters: {'learning_rate': 0.0262806927205274, 'depth': 7, 'l2_leaf_reg': 1.256237995562014, 'min_data_in_leaf': 96, 'border_count': 169, 'random_strength': 0.6056472861018262, 'subsample': 0.8366879716190919, 'rsm': 0.6230085835338948}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:26:32,595] Trial 35 finished with value: 0.9010663000131219 and parameters: {'learning_rate': 0.05957717329342168, 'depth': 7, 'l2_leaf_reg': 2.350282013418458, 'min_data_in_leaf': 94, 'border_count': 165, 'random_strength': 0.5727150769412359, 'subsample': 0.8304528001851783, 'rsm': 0.6398735673872421}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:26:38,766] Trial 36 finished with value: 0.8992805755395683 and parameters: {'learning_rate': 0.0276375351554165, 'depth': 6, 'l2_leaf_reg': 0.6669694718459935, 'min_data_in_leaf': 100, 'border_count': 177, 'random_strength': 0.4052138490301806, 'subsample': 0.8451361101476125, 'rsm': 0.590765681279062}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:26:46,625] Trial 37 finished with value: 0.8953126158866722 and parameters: {'learning_rate': 0.0010517651012582156, 'depth': 7, 'l2_leaf_reg': 0.9343415517626279, 'min_data_in_leaf': 83, 'border_count': 196, 'random_strength': 0.21679345066499367, 'subsample': 0.7941246672823459, 'rsm': 0.4716875129678095}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:26:51,531] Trial 38 finished with value: 0.9006840522823613 and parameters: {'learning_rate': 0.07756115394504019, 'depth': 5, 'l2_leaf_reg': 5.638665888711229, 'min_data_in_leaf': 94, 'border_count': 120, 'random_strength': 0.5925882257758498, 'subsample': 0.5004352683414749, 'rsm': 0.6049972588451394}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:27:01,372] Trial 39 finished with value: 0.897740174236503 and parameters: {'learning_rate': 0.047053095739677926, 'depth': 8, 'l2_leaf_reg': 0.11904993522042047, 'min_data_in_leaf': 56, 'border_count': 151, 'random_strength': 0.7036536607362491, 'subsample': 0.46054969666715484, 'rsm': 0.5604635678694877}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:27:06,975] Trial 40 finished with value: 0.8989040329988189 and parameters: {'learning_rate': 0.011133597847867462, 'depth': 6, 'l2_leaf_reg': 1.0865327606185516e-08, 'min_data_in_leaf': 79, 'border_count': 80, 'random_strength': 0.7857902482492858, 'subsample': 0.6255653701128727, 'rsm': 0.663804682103636}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:27:14,592] Trial 41 finished with value: 0.9011347622932583 and parameters: {'learning_rate': 0.06133333926967265, 'depth': 7, 'l2_leaf_reg': 1.993466530550716, 'min_data_in_leaf': 94, 'border_count': 167, 'random_strength': 0.5562930120961714, 'subsample': 0.8115692146174998, 'rsm': 0.6271277922724591}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:27:22,271] Trial 42 finished with value: 0.897723058666469 and parameters: {'learning_rate': 0.09828649270521454, 'depth': 7, 'l2_leaf_reg': 0.5474309334287478, 'min_data_in_leaf': 94, 'border_count': 172, 'random_strength': 0.6188269580243467, 'subsample': 0.7048077499795768, 'rsm': 0.629472967322358}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:27:31,761] Trial 43 finished with value: 0.90067834709235 and parameters: {'learning_rate': 0.03360566906788363, 'depth': 8, 'l2_leaf_reg': 2.636405622680786, 'min_data_in_leaf': 82, 'border_count': 129, 'random_strength': 0.5081700901234646, 'subsample': 0.8069732385363199, 'rsm': 0.5691375944397565}. Best is trial 32 with value: 0.9032171566474021.
# ...
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:35:16,492] Trial 85 finished with value: 0.9031658099373 and parameters: {'learning_rate': 0.034416476297142486, 'depth': 9, 'l2_leaf_reg': 2.9395679808256086, 'min_data_in_leaf': 9, 'border_count': 246, 'random_strength': 0.43427339889288324, 'subsample': 0.4687152497719459, 'rsm': 0.4474219052673356}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:35:48,955] Trial 86 finished with value: 0.9009293754528493 and parameters: {'learning_rate': 0.03576337567613482, 'depth': 10, 'l2_leaf_reg': 2.9098948623662206, 'min_data_in_leaf': 8, 'border_count': 249, 'random_strength': 0.42643210674777277, 'subsample': 0.4064100403652021, 'rsm': 0.44456442654636774}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:36:06,241] Trial 87 finished with value: 0.9014599581239052 and parameters: {'learning_rate': 0.0475409030612173, 'depth': 9, 'l2_leaf_reg': 1.5093379075380435, 'min_data_in_leaf': 13, 'border_count': 218, 'random_strength': 0.38749473253451355, 'subsample': 0.4722841291554234, 'rsm': 0.401369013531999}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:36:23,113] Trial 88 finished with value: 0.8970498462451292 and parameters: {'learning_rate': 0.05394704757750929, 'depth': 9, 'l2_leaf_reg': 0.03732202786610527, 'min_data_in_leaf': 12, 'border_count': 218, 'random_strength': 0.3961851814507367, 'subsample': 0.46628644569615646, 'rsm': 0.4148256678617107}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:36:40,319] Trial 89 finished with value: 0.8961427210333239 and parameters: {'learning_rate': 0.08504734861450515, 'depth': 9, 'l2_leaf_reg': 0.6267756634832132, 'min_data_in_leaf': 10, 'border_count': 225, 'random_strength': 0.3490833425424914, 'subsample': 0.44438365771248567, 'rsm': 0.4013226475845376}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:36:58,555] Trial 90 finished with value: 0.8984875541279903 and parameters: {'learning_rate': 0.06337749674484094, 'depth': 9, 'l2_leaf_reg': 0.20966249791518254, 'min_data_in_leaf': 5, 'border_count': 248, 'random_strength': 0.380466720808497, 'subsample': 0.4882951148914822, 'rsm': 0.42604555943781575}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:37:14,689] Trial 91 finished with value: 0.901083415583156 and parameters: {'learning_rate': 0.0481620678586229, 'depth': 9, 'l2_leaf_reg': 2.348439898403423, 'min_data_in_leaf': 8, 'border_count': 203, 'random_strength': 0.48990339535077176, 'subsample': 0.5080231212678691, 'rsm': 0.7836930991331259}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:37:32,430] Trial 92 finished with value: 0.9022016328253812 and parameters: {'learning_rate': 0.03989276369828037, 'depth': 9, 'l2_leaf_reg': 1.3656830570781666, 'min_data_in_leaf': 17, 'border_count': 238, 'random_strength': 0.45011497885332286, 'subsample': 0.47903187815800374, 'rsm': 0.4611145346263651}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:37:50,113] Trial 93 finished with value: 0.899503077950011 and parameters: {'learning_rate': 0.040296771311185454, 'depth': 9, 'l2_leaf_reg': 0.0014958453470053773, 'min_data_in_leaf': 13, 'border_count': 240, 'random_strength': 0.4219460183523936, 'subsample': 0.47916139016878395, 'rsm': 0.46847176764873505}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:38:20,236] Trial 94 finished with value: 0.8887259740185648 and parameters: {'learning_rate': 0.05194273210731841, 'depth': 10, 'l2_leaf_reg': 5.281161105689185e-05, 'min_data_in_leaf': 18, 'border_count': 233, 'random_strength': 0.4680957189300355, 'subsample': 0.41509209625503735, 'rsm': 0.4356986452995581}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:38:37,704] Trial 95 finished with value: 0.8890796957992686 and parameters: {'learning_rate': 0.04541273588094346, 'depth': 9, 'l2_leaf_reg': 2.2943117155989846e-05, 'min_data_in_leaf': 9, 'border_count': 241, 'random_strength': 0.2894344133049936, 'subsample': 0.45297048794812955, 'rsm': 0.4442521584845891}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:38:56,645] Trial 96 finished with value: 0.9011689934333263 and parameters: {'learning_rate': 0.03390455390408926, 'depth': 9, 'l2_leaf_reg': 0.38915121084167514, 'min_data_in_leaf': 13, 'border_count': 225, 'random_strength': 0.31779725227036554, 'subsample': 0.5240996182911231, 'rsm': 0.5023419615239906}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:39:24,183] Trial 97 finished with value: 0.9000108398610216 and parameters: {'learning_rate': 0.03854848153049248, 'depth': 10, 'l2_leaf_reg': 1.0412381897246106, 'min_data_in_leaf': 20, 'border_count': 197, 'random_strength': 0.45119613157732036, 'subsample': 0.471259209252974, 'rsm': 0.4661228710608287}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:39:41,795] Trial 98 finished with value: 0.8871684571454652 and parameters: {'learning_rate': 0.067798257795363, 'depth': 9, 'l2_leaf_reg': 0.0002621836429288129, 'min_data_in_leaf': 6, 'border_count': 212, 'random_strength': 0.42280860291403377, 'subsample': 0.416653287944153, 'rsm': 0.4127833523590965}. Best is trial 32 with value: 0.9032171566474021.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:18: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3380375053.py:20: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg':        trial.suggest_loguniform('l2_leaf_reg', 1e-8, 10.0),
# [I 2025-04-28 08:39:59,406] Trial 99 finished with value: 0.9001819955613624 and parameters: {'learning_rate': 0.0050168834403675625, 'depth': 9, 'l2_leaf_reg': 3.2799302712499645, 'min_data_in_leaf': 16, 'border_count': 218, 'random_strength': 0.3453494505017014, 'subsample': 0.5032206738237459, 'rsm': 0.4875631305266315}. Best is trial 32 with value: 0.9032171566474021.
# ▶ Best CatBoost parameters:
#    learning_rate: 0.03688688094534395
#    depth: 7
#    l2_leaf_reg: 0.06202998934307267
#    min_data_in_leaf: 93
#    border_count: 141
#    random_strength: 0.8195253675619897
#    subsample: 0.46528052286516963
#    rsm: 0.5808697982329277
# ▶ Best hold-out AUC: 0.9032

# %%
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier

# pull in the best params & fixed iteration count
best = study.best_trial.params
ROUNDS = 300  # same as your Cell 1 ROUNDS
cb_params = {
    'learning_rate':    best['learning_rate'],
    'depth':            best['depth'],
    'l2_leaf_reg':      best['l2_leaf_reg'],
    'min_data_in_leaf': best['min_data_in_leaf'],
    'border_count':     best['border_count'],
    'random_strength':  best['random_strength'],
    'subsample':        best['subsample'],
    'rsm':              best['rsm'],
    'bootstrap_type':   'Bernoulli',
    'objective':        'Logloss',
    'eval_metric':      'AUC',
    'task_type':        'CPU',
    'verbose':          False,
    'random_seed':      SEED
}

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
fold_aucs = []

for fold, (tr_idx, va_idx) in enumerate(kf.split(train_features, y), 1):
    X_tr, X_va = train_features.iloc[tr_idx], train_features.iloc[va_idx]
    y_tr, y_va = y.iloc[tr_idx], y.iloc[va_idx]

    # majority/minority in this fold
    arr = y_tr.values
    maj_idx = np.where(arr==0)[0]
    rar_idx = np.where(arr==1)[0]
    splits = np.array_split(np.random.RandomState(SEED).permutation(maj_idx), N_MODELS)

    # ensemble for this fold
    preds = np.zeros(len(X_va))
    for grp in splits:
        idx = np.sort(np.concatenate([rar_idx, grp]))
        m = CatBoostClassifier(**cb_params, iterations=ROUNDS)
        m.fit(X_tr.iloc[idx], y_tr.iloc[idx])
        preds += m.predict_proba(X_va)[:,1]
    preds /= N_MODELS

    auc = roc_auc_score(y_va, preds)
    fold_aucs.append(auc)
    print(f"Fold {fold} AUC: {auc:.4f}")

print(f"\nMean CV AUC: {np.mean(fold_aucs):.4f} ± {np.std(fold_aucs):.4f}")
# Out:
# Fold 1 AUC: 0.8901
# Fold 2 AUC: 0.8990
# Fold 3 AUC: 0.8895
# Fold 4 AUC: 0.8855
# Fold 5 AUC: 0.8890
#
# Mean CV AUC: 0.8906 ± 0.0045

# %%
import numpy as np
import joblib
from catboost import CatBoostClassifier

# pull best params & rounds
best = study.best_trial.params

cb_params = {
    'learning_rate':    best['learning_rate'],
    'depth':            best['depth'],
    'l2_leaf_reg':      best['l2_leaf_reg'],
    'min_data_in_leaf': best['min_data_in_leaf'],
    'border_count':     best['border_count'],
    'random_strength':  best['random_strength'],
    'subsample':        best['subsample'],
    'rsm':              best['rsm'],
    'bootstrap_type':   'Bernoulli',
    'objective':        'Logloss',
    'eval_metric':      'AUC',
    'task_type':        'CPU',
    'verbose':          False,
    'random_seed':      SEED
}

# prepare splits on full train
arr = y.values
maj_idx = np.where(arr==0)[0]
rar_idx = np.where(arr==1)[0]
splits = np.array_split(np.random.RandomState(SEED).permutation(maj_idx), N_MODELS)

ensemble = []
for i, grp in enumerate(splits, 1):
    idx = np.sort(np.concatenate([rar_idx, grp]))
    X_sub, y_sub = train_features.iloc[idx], y.iloc[idx]
    print(f"Ensembling member {i}: majority={len(grp)}, minority={len(rar_idx)}")
    m = CatBoostClassifier(**cb_params, iterations=ROUNDS)
    m.fit(X_sub, y_sub)
    ensemble.append(m)

# predict test
test_preds = np.mean([m.predict_proba(test_features)[:,1] for m in ensemble], axis=0)

# write submission
sub = submission_format.copy()
sub['coppaRisk'] = test_preds
sub.to_csv('catboost_majority_ensemble.csv', index=False)
print(" Written catboost_majority_ensemble.csv")

# save models
joblib.dump(ensemble, 'catboost_majority_ensemble.pkl')
print(" Saved catboost_majority_ensemble.pkl")
# Out:
# Ensembling member 1: majority=701, minority=696
# Ensembling member 2: majority=701, minority=696
# Ensembling member 3: majority=701, minority=696
# Ensembling member 4: majority=701, minority=696
# Ensembling member 5: majority=700, minority=696
# Ensembling member 6: majority=700, minority=696
# Ensembling member 7: majority=700, minority=696
# Ensembling member 8: majority=700, minority=696
# Ensembling member 9: majority=700, minority=696
#  Written catboost_majority_ensemble.csv
#  Saved catboost_majority_ensemble.pkl

# %%
best
# Out:
# {'learning_rate': 0.03688688094534395,
#  'depth': 7,
#  'l2_leaf_reg': 0.06202998934307267,
#  'min_data_in_leaf': 93,
#  'border_count': 141,
#  'random_strength': 0.8195253675619897,
#  'subsample': 0.46528052286516963,
#  'rsm': 0.5808697982329277}

# %% [markdown]
# {'learning_rate': 0.06834041243586388,
#  'depth': 7,
#  'l2_leaf_reg': 9.363606651596735,
#  'min_data_in_leaf': 43,
#  'border_count': 148,
#  'random_strength': 0.9514868218379223,
#  'subsample': 0.6011198068621887,
#  'rsm': 0.718895532911034}

# %%
best
# Out:
# {'learning_rate': 0.03688688094534395,
#  'depth': 7,
#  'l2_leaf_reg': 0.06202998934307267,
#  'min_data_in_leaf': 93,
#  'border_count': 141,
#  'random_strength': 0.8195253675619897,
#  'subsample': 0.46528052286516963,
#  'rsm': 0.5808697982329277}

# %% [markdown]
# {'learning_rate': 0.06834041243586388,
#  'depth': 7,
#  'l2_leaf_reg': 9.363606651596735,
#  'min_data_in_leaf': 43,
#  'border_count': 148,
#  'random_strength': 0.9514868218379223,
#  'subsample': 0.6011198068621887,
#  'rsm': 0.718895532911034}

# %% [markdown]
# # Lightgbm

# %%
# ┌───────────────────────────────────────────────────────────────┐
# Cell B1: Tune LightGBM via Optuna + majority/minority hold-out
# └───────────────────────────────────────────────────────────────┘
import numpy as np
import optuna
import lightgbm as lgb
from sklearn.metrics import roc_auc_score

N_MODELS = 9
SEED     = 42
ROUNDS   = 300

def objective_lgb(trial):
    params = {
        'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
        'num_leaves':         trial.suggest_int('num_leaves', 20, 300),
        'max_depth':          trial.suggest_int('max_depth', 3, 15),
        'feature_fraction':   trial.suggest_float('feature_fraction', 0.4, 1.0),
        'bagging_fraction':   trial.suggest_float('bagging_fraction', 0.4, 1.0),
        'bagging_freq':       trial.suggest_int('bagging_freq', 1, 10),
        'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
        'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
        'min_child_samples':  trial.suggest_int('min_child_samples', 5, 200),
        'objective':          'binary',
        'metric':             'auc',
        'verbosity':          -1,
        'boosting_type':      'gbdt',
        'seed':               SEED
    }

    preds = np.zeros(len(X_val), dtype=float)
    arr = y_train.values
    maj_idx = np.where(arr == 0)[0]
    rar_idx = np.where(arr == 1)[0]
    rng = np.random.RandomState(SEED)
    splits = np.array_split(rng.permutation(maj_idx), N_MODELS)

    for grp in splits:
        idx = np.sort(np.concatenate([rar_idx, grp]))
        X_sub, y_sub = X_train.iloc[idx], y_train.iloc[idx]
        dsub = lgb.Dataset(X_sub, label=y_sub)
        m = lgb.train(params, dsub, num_boost_round=ROUNDS)
        preds += m.predict(X_val)

    preds /= N_MODELS
    return roc_auc_score(y_val, preds)

study_lgb = optuna.create_study(direction='maximize')
study_lgb.optimize(objective_lgb, n_trials=200, timeout=3600)

best_lgb = study_lgb.best_trial.params
print("▶ Best LGB params:", best_lgb)
print(f"▶ Hold-out AUC: {study_lgb.best_value:.4f}")
# Out:
# [I 2025-04-28 08:40:44,933] A new study created in memory with name: no-name-0136c882-a6e5-4d5d-a775-ea4a22ff1599
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:45,461] Trial 0 finished with value: 0.8014479772248815 and parameters: {'learning_rate': 0.05484028608626748, 'num_leaves': 244, 'max_depth': 13, 'feature_fraction': 0.8262147168545062, 'bagging_fraction': 0.7199385928488657, 'bagging_freq': 5, 'reg_alpha': 7.458714146483146e-07, 'reg_lambda': 2.5086344632339282e-08, 'min_child_samples': 159}. Best is trial 0 with value: 0.8014479772248815.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:46,108] Trial 1 finished with value: 0.8794835662001724 and parameters: {'learning_rate': 0.05245794943930141, 'num_leaves': 32, 'max_depth': 15, 'feature_fraction': 0.668505145383619, 'bagging_fraction': 0.8448598275480419, 'bagging_freq': 10, 'reg_alpha': 2.622498068118028e-06, 'reg_lambda': 1.7663377246109e-06, 'min_child_samples': 91}. Best is trial 1 with value: 0.8794835662001724.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:46,735] Trial 2 finished with value: 0.8522127579459033 and parameters: {'learning_rate': 0.00010108982162903494, 'num_leaves': 157, 'max_depth': 9, 'feature_fraction': 0.8790638877473647, 'bagging_fraction': 0.5310514609183874, 'bagging_freq': 2, 'reg_alpha': 0.02510118478044797, 'reg_lambda': 2.3919261346694233e-07, 'min_child_samples': 76}. Best is trial 1 with value: 0.8794835662001724.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:47,149] Trial 3 finished with value: 0.7274345472075947 and parameters: {'learning_rate': 0.003363450788122535, 'num_leaves': 258, 'max_depth': 9, 'feature_fraction': 0.7853984119631099, 'bagging_fraction': 0.6317420639385819, 'bagging_freq': 10, 'reg_alpha': 0.0003803134954375658, 'reg_lambda': 0.092469923192802, 'min_child_samples': 167}. Best is trial 1 with value: 0.8794835662001724.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:47,568] Trial 4 finished with value: 0.7269895423867092 and parameters: {'learning_rate': 0.0009440825320975058, 'num_leaves': 185, 'max_depth': 13, 'feature_fraction': 0.9348399625741848, 'bagging_fraction': 0.6166425831953736, 'bagging_freq': 4, 'reg_alpha': 0.050466183603700136, 'reg_lambda': 2.1789279797064136e-06, 'min_child_samples': 163}. Best is trial 1 with value: 0.8794835662001724.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:48,380] Trial 5 finished with value: 0.8755783636374009 and parameters: {'learning_rate': 0.008577291382178977, 'num_leaves': 175, 'max_depth': 5, 'feature_fraction': 0.5781187160752309, 'bagging_fraction': 0.8346006594801759, 'bagging_freq': 1, 'reg_alpha': 2.0337234023108248e-06, 'reg_lambda': 1.741226247028219e-05, 'min_child_samples': 100}. Best is trial 1 with value: 0.8794835662001724.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:49,044] Trial 6 finished with value: 0.84109049001877 and parameters: {'learning_rate': 0.004880529530564848, 'num_leaves': 170, 'max_depth': 14, 'feature_fraction': 0.4693625040939672, 'bagging_fraction': 0.5071269045301341, 'bagging_freq': 1, 'reg_alpha': 3.902818831418486e-07, 'reg_lambda': 7.5080563608499755, 'min_child_samples': 88}. Best is trial 1 with value: 0.8794835662001724.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:49,846] Trial 7 finished with value: 0.8797631205107286 and parameters: {'learning_rate': 0.041906530390007704, 'num_leaves': 249, 'max_depth': 8, 'feature_fraction': 0.9785869331439976, 'bagging_fraction': 0.6074703885076446, 'bagging_freq': 7, 'reg_alpha': 1.0083422884014376e-05, 'reg_lambda': 4.718051556340119e-08, 'min_child_samples': 69}. Best is trial 7 with value: 0.8797631205107286.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:50,650] Trial 8 finished with value: 0.8824844961461442 and parameters: {'learning_rate': 0.02209306419257357, 'num_leaves': 167, 'max_depth': 10, 'feature_fraction': 0.9150277207269668, 'bagging_fraction': 0.9505301182646106, 'bagging_freq': 3, 'reg_alpha': 0.1659214332143465, 'reg_lambda': 0.01214584230358167, 'min_child_samples': 85}. Best is trial 8 with value: 0.8824844961461442.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:52,762] Trial 9 finished with value: 0.8894334175799725 and parameters: {'learning_rate': 0.033226349243464744, 'num_leaves': 202, 'max_depth': 13, 'feature_fraction': 0.9394029256828867, 'bagging_fraction': 0.8589528191066276, 'bagging_freq': 5, 'reg_alpha': 4.401110143723132e-07, 'reg_lambda': 1.62650875659625e-08, 'min_child_samples': 23}. Best is trial 9 with value: 0.8894334175799725.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:53,764] Trial 10 finished with value: 0.895207069871462 and parameters: {'learning_rate': 0.0005747979827120688, 'num_leaves': 81, 'max_depth': 4, 'feature_fraction': 0.7215789778006396, 'bagging_fraction': 0.9974218211635542, 'bagging_freq': 7, 'reg_alpha': 2.0582251246072027e-08, 'reg_lambda': 0.0006321841228960882, 'min_child_samples': 17}. Best is trial 10 with value: 0.895207069871462.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:54,539] Trial 11 finished with value: 0.8934127876128914 and parameters: {'learning_rate': 0.0007013301683262675, 'num_leaves': 75, 'max_depth': 3, 'feature_fraction': 0.70092010087374, 'bagging_fraction': 0.9864556416626775, 'bagging_freq': 7, 'reg_alpha': 1.5818603627099516e-08, 'reg_lambda': 0.0029751343297407624, 'min_child_samples': 9}. Best is trial 10 with value: 0.895207069871462.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:55,282] Trial 12 finished with value: 0.8940860000342311 and parameters: {'learning_rate': 0.0006330130352349778, 'num_leaves': 68, 'max_depth': 3, 'feature_fraction': 0.6865904209992305, 'bagging_fraction': 0.9981417176493632, 'bagging_freq': 7, 'reg_alpha': 1.0907685829924582e-08, 'reg_lambda': 0.0003927240791852123, 'min_child_samples': 10}. Best is trial 10 with value: 0.895207069871462.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:55,916] Trial 13 finished with value: 0.8883037899577245 and parameters: {'learning_rate': 0.0004975626717713934, 'num_leaves': 102, 'max_depth': 3, 'feature_fraction': 0.6809647680380665, 'bagging_fraction': 0.9986476026090485, 'bagging_freq': 8, 'reg_alpha': 4.4817218162401674e-08, 'reg_lambda': 0.00013340029990744763, 'min_child_samples': 43}. Best is trial 10 with value: 0.895207069871462.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:56,629] Trial 14 finished with value: 0.8730452592723601 and parameters: {'learning_rate': 0.00017809121547964673, 'num_leaves': 113, 'max_depth': 6, 'feature_fraction': 0.5868940899473416, 'bagging_fraction': 0.9095450639503208, 'bagging_freq': 8, 'reg_alpha': 6.4768929235280215, 'reg_lambda': 0.0005300466916943851, 'min_child_samples': 40}. Best is trial 10 with value: 0.895207069871462.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:57,807] Trial 15 finished with value: 0.8966362199693061 and parameters: {'learning_rate': 0.0015765831093734353, 'num_leaves': 52, 'max_depth': 5, 'feature_fraction': 0.7758885289311535, 'bagging_fraction': 0.40972589470046483, 'bagging_freq': 7, 'reg_alpha': 6.172088342859114e-05, 'reg_lambda': 0.0671980781585456, 'min_child_samples': 5}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:58,274] Trial 16 finished with value: 0.7267784503562891 and parameters: {'learning_rate': 0.001871170439811982, 'num_leaves': 35, 'max_depth': 6, 'feature_fraction': 0.786757225499464, 'bagging_fraction': 0.42358747992845686, 'bagging_freq': 6, 'reg_alpha': 7.454519074872426e-05, 'reg_lambda': 0.3067423084877231, 'min_child_samples': 128}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:58,633] Trial 17 finished with value: 0.6847911044677342 and parameters: {'learning_rate': 0.0003081073934904493, 'num_leaves': 121, 'max_depth': 6, 'feature_fraction': 0.7557305161075879, 'bagging_fraction': 0.40138843642175986, 'bagging_freq': 9, 'reg_alpha': 0.0008996855512442301, 'reg_lambda': 0.5810533379469888, 'min_child_samples': 200}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:40:59,521] Trial 18 finished with value: 0.8811066927584024 and parameters: {'learning_rate': 0.0015398398440666363, 'num_leaves': 72, 'max_depth': 5, 'feature_fraction': 0.5810179773847991, 'bagging_fraction': 0.7439181409057715, 'bagging_freq': 6, 'reg_alpha': 0.0031771948862855458, 'reg_lambda': 0.01397260555117153, 'min_child_samples': 53}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:00,437] Trial 19 finished with value: 0.8879671837470546 and parameters: {'learning_rate': 0.015201133484148444, 'num_leaves': 27, 'max_depth': 11, 'feature_fraction': 0.4036840684509095, 'bagging_fraction': 0.7809794469014123, 'bagging_freq': 8, 'reg_alpha': 2.873351760445274e-05, 'reg_lambda': 6.963439571415884, 'min_child_samples': 29}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:00,898] Trial 20 finished with value: 0.725015546642781 and parameters: {'learning_rate': 0.0014036623766231333, 'num_leaves': 137, 'max_depth': 7, 'feature_fraction': 0.8658918070818278, 'bagging_fraction': 0.4831157146407572, 'bagging_freq': 4, 'reg_alpha': 8.851267051477816, 'reg_lambda': 3.6653057075350776e-05, 'min_child_samples': 117}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:01,873] Trial 21 finished with value: 0.8964051597738463 and parameters: {'learning_rate': 0.0003190344715764243, 'num_leaves': 68, 'max_depth': 4, 'feature_fraction': 0.7231487609205933, 'bagging_fraction': 0.9282429920392257, 'bagging_freq': 7, 'reg_alpha': 6.625892561649632e-08, 'reg_lambda': 0.0006978349094428624, 'min_child_samples': 6}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:02,902] Trial 22 finished with value: 0.8946479612503494 and parameters: {'learning_rate': 0.00025265382248674417, 'num_leaves': 58, 'max_depth': 4, 'feature_fraction': 0.7303155342872993, 'bagging_fraction': 0.9112383477757202, 'bagging_freq': 9, 'reg_alpha': 1.0925432697732445e-07, 'reg_lambda': 0.002165152698644159, 'min_child_samples': 10}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:03,762] Trial 23 finished with value: 0.891370329588827 and parameters: {'learning_rate': 0.0004494708962628116, 'num_leaves': 51, 'max_depth': 4, 'feature_fraction': 0.6457612643252116, 'bagging_fraction': 0.9160749271437738, 'bagging_freq': 6, 'reg_alpha': 1.0733971002534491e-07, 'reg_lambda': 0.031369552415419, 'min_child_samples': 27}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:04,584] Trial 24 finished with value: 0.8552108352968695 and parameters: {'learning_rate': 0.00012495731131643227, 'num_leaves': 93, 'max_depth': 5, 'feature_fraction': 0.6185900673615007, 'bagging_fraction': 0.6633253188067951, 'bagging_freq': 7, 'reg_alpha': 5.759657112545257e-06, 'reg_lambda': 0.001840127023848114, 'min_child_samples': 60}. Best is trial 15 with value: 0.8966362199693061.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:07,601] Trial 25 finished with value: 0.9030574113270843 and parameters: {'learning_rate': 0.002529446206441514, 'num_leaves': 95, 'max_depth': 7, 'feature_fraction': 0.8239574195493125, 'bagging_fraction': 0.8053144089211188, 'bagging_freq': 9, 'reg_alpha': 2.998392707863153e-05, 'reg_lambda': 6.916361117822022e-05, 'min_child_samples': 5}. Best is trial 25 with value: 0.9030574113270843.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:08,479] Trial 26 finished with value: 0.8949531889159569 and parameters: {'learning_rate': 0.004719584302105401, 'num_leaves': 128, 'max_depth': 7, 'feature_fraction': 0.8303217248084609, 'bagging_fraction': 0.5562666828214908, 'bagging_freq': 9, 'reg_alpha': 0.00011003242698179192, 'reg_lambda': 5.10380796702588e-05, 'min_child_samples': 43}. Best is trial 25 with value: 0.9030574113270843.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:09,607] Trial 27 finished with value: 0.8874822425960895 and parameters: {'learning_rate': 0.09219912058340549, 'num_leaves': 284, 'max_depth': 7, 'feature_fraction': 0.8007400622857764, 'bagging_fraction': 0.805136773727136, 'bagging_freq': 8, 'reg_alpha': 0.0016814330272825891, 'reg_lambda': 6.392016841729124e-06, 'min_child_samples': 32}. Best is trial 25 with value: 0.9030574113270843.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:10,416] Trial 28 finished with value: 0.8945053315000657 and parameters: {'learning_rate': 0.002562494902388208, 'num_leaves': 45, 'max_depth': 8, 'feature_fraction': 0.8655846109794434, 'bagging_fraction': 0.764600519641142, 'bagging_freq': 9, 'reg_alpha': 2.813830861163579e-05, 'reg_lambda': 0.4762386995234368, 'min_child_samples': 58}. Best is trial 25 with value: 0.9030574113270843.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:10,960] Trial 29 finished with value: 0.8230449740128596 and parameters: {'learning_rate': 0.007114706742635409, 'num_leaves': 20, 'max_depth': 5, 'feature_fraction': 0.8334467746267554, 'bagging_fraction': 0.7125378002160386, 'bagging_freq': 5, 'reg_alpha': 0.009235998791549764, 'reg_lambda': 0.00014029552912179211, 'min_child_samples': 140}. Best is trial 25 with value: 0.9030574113270843.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:12,433] Trial 30 finished with value: 0.896416570153869 and parameters: {'learning_rate': 0.0009078803392202115, 'num_leaves': 143, 'max_depth': 8, 'feature_fraction': 0.7565418175022283, 'bagging_fraction': 0.6793662513327227, 'bagging_freq': 10, 'reg_alpha': 0.00017283206202551346, 'reg_lambda': 0.006783381884255144, 'min_child_samples': 19}. Best is trial 25 with value: 0.9030574113270843.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:41:15,394] Trial 31 finished with value: 0.9033826071577313 and parameters: {'learning_rate': 0.0010141004292218744, 'num_leaves': 147, 'max_depth': 8, 'feature_fraction': 0.7523060990315699, 'bagging_fraction': 0.6999732175783152, 'bagging_freq': 10, 'reg_alpha': 0.00023856470894699253, 'reg_lambda': 0.00412442975031381, 'min_child_samples': 5}. Best is trial 31 with value: 0.9033826071577313.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# ...
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:21,045] Trial 189 finished with value: 0.9044722984499 and parameters: {'learning_rate': 0.007797288723036564, 'num_leaves': 197, 'max_depth': 10, 'feature_fraction': 0.5415789561190059, 'bagging_fraction': 0.7637205669827424, 'bagging_freq': 6, 'reg_alpha': 3.7396160628311435e-08, 'reg_lambda': 0.003704493408116324, 'min_child_samples': 5}. Best is trial 154 with value: 0.9047632631404788.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:23,080] Trial 190 finished with value: 0.8977173534764575 and parameters: {'learning_rate': 0.005358325448647546, 'num_leaves': 193, 'max_depth': 10, 'feature_fraction': 0.5401782582747179, 'bagging_fraction': 0.7538112691719724, 'bagging_freq': 6, 'reg_alpha': 3.6537358494899434e-08, 'reg_lambda': 0.0027530433935272574, 'min_child_samples': 14}. Best is trial 154 with value: 0.9047632631404788.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:26,706] Trial 191 finished with value: 0.9048317254206152 and parameters: {'learning_rate': 0.007505906858196698, 'num_leaves': 177, 'max_depth': 10, 'feature_fraction': 0.6009712042224474, 'bagging_fraction': 0.764757532881105, 'bagging_freq': 6, 'reg_alpha': 3.783155365098816e-08, 'reg_lambda': 0.0034876075212315833, 'min_child_samples': 5}. Best is trial 191 with value: 0.9048317254206152.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:29,947] Trial 192 finished with value: 0.9031201684172091 and parameters: {'learning_rate': 0.007389585464104063, 'num_leaves': 197, 'max_depth': 10, 'feature_fraction': 0.5568718965136602, 'bagging_fraction': 0.7678178783393281, 'bagging_freq': 6, 'reg_alpha': 4.0255305785244005e-08, 'reg_lambda': 0.0020514016138491052, 'min_child_samples': 8}. Best is trial 191 with value: 0.9048317254206152.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:34,406] Trial 193 finished with value: 0.9047347371904222 and parameters: {'learning_rate': 0.00776530530457632, 'num_leaves': 186, 'max_depth': 10, 'feature_fraction': 0.5983102974307517, 'bagging_fraction': 0.7641978389878362, 'bagging_freq': 6, 'reg_alpha': 5.8652858305322466e-08, 'reg_lambda': 0.0006952738698397263, 'min_child_samples': 5}. Best is trial 191 with value: 0.9048317254206152.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:38,301] Trial 194 finished with value: 0.9033027344975725 and parameters: {'learning_rate': 0.006848493011244328, 'num_leaves': 182, 'max_depth': 10, 'feature_fraction': 0.5851183784842107, 'bagging_fraction': 0.7797350493820021, 'bagging_freq': 6, 'reg_alpha': 1.63728152486151e-07, 'reg_lambda': 0.0006807071923105158, 'min_child_samples': 10}. Best is trial 191 with value: 0.9048317254206152.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:42,484] Trial 195 finished with value: 0.9039474209688553 and parameters: {'learning_rate': 0.005555099921100209, 'num_leaves': 187, 'max_depth': 10, 'feature_fraction': 0.5907321442384454, 'bagging_fraction': 0.751538014812665, 'bagging_freq': 6, 'reg_alpha': 7.253869929999513e-08, 'reg_lambda': 0.0002450483458983777, 'min_child_samples': 5}. Best is trial 191 with value: 0.9048317254206152.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:45,111] Trial 196 finished with value: 0.901710986484405 and parameters: {'learning_rate': 0.007721019582146113, 'num_leaves': 206, 'max_depth': 10, 'feature_fraction': 0.5995349584315399, 'bagging_fraction': 0.7396941936287733, 'bagging_freq': 6, 'reg_alpha': 1.0930257898044175e-07, 'reg_lambda': 0.003228182624154284, 'min_child_samples': 12}. Best is trial 191 with value: 0.9048317254206152.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:48,116] Trial 197 finished with value: 0.901728102054439 and parameters: {'learning_rate': 0.007959610600185527, 'num_leaves': 178, 'max_depth': 11, 'feature_fraction': 0.5460415049816276, 'bagging_fraction': 0.7126661463294045, 'bagging_freq': 6, 'reg_alpha': 5.244779466596841e-08, 'reg_lambda': 0.0016388669995931998, 'min_child_samples': 9}. Best is trial 191 with value: 0.9048317254206152.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:50,424] Trial 198 finished with value: 0.897289464225606 and parameters: {'learning_rate': 0.003466068335172759, 'num_leaves': 197, 'max_depth': 11, 'feature_fraction': 0.5773430902315291, 'bagging_fraction': 0.7855497492471956, 'bagging_freq': 6, 'reg_alpha': 4.989516557628914e-08, 'reg_lambda': 0.00039872018058228576, 'min_child_samples': 16}. Best is trial 191 with value: 0.9048317254206152.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-4, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3735135392.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:47:54,071] Trial 199 finished with value: 0.9042041545193662 and parameters: {'learning_rate': 0.004598707634903748, 'num_leaves': 165, 'max_depth': 10, 'feature_fraction': 0.6027543358813012, 'bagging_fraction': 0.7639343695975847, 'bagging_freq': 6, 'reg_alpha': 2.000649565659522e-07, 'reg_lambda': 0.0008475848173797228, 'min_child_samples': 5}. Best is trial 191 with value: 0.9048317254206152.
# ▶ Best LGB params: {'learning_rate': 0.007505906858196698, 'num_leaves': 177, 'max_depth': 10, 'feature_fraction': 0.6009712042224474, 'bagging_fraction': 0.764757532881105, 'bagging_freq': 6, 'reg_alpha': 3.783155365098816e-08, 'reg_lambda': 0.0034876075212315833, 'min_child_samples': 5}
# ▶ Hold-out AUC: 0.9048

# %%
# ┌───────────────────────────────────────────────────────────────┐
# Cell B2: 5-Fold Stratified CV of LightGBM majority/minority
# └───────────────────────────────────────────────────────────────┘
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import lightgbm as lgb

ROUNDS = 300
lgb_params = dict(best_lgb)
lgb_params.update({
    'objective':'binary','metric':'auc',
    'verbosity':-1,'boosting_type':'gbdt','seed':SEED
})

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
cv_aucs = []
for fold, (tr, va) in enumerate(kf.split(train_features, y), 1):
    preds = np.zeros(len(va), dtype=float)
    X_tr, X_va = train_features.iloc[tr], train_features.iloc[va]
    y_tr, y_va = y.iloc[tr], y.iloc[va]

    arr = y_tr.values
    maj_idx = np.where(arr == 0)[0]
    rar_idx = np.where(arr == 1)[0]
    splits = np.array_split(np.random.RandomState(SEED).permutation(maj_idx), N_MODELS)

    for grp in splits:
        idx = np.sort(np.concatenate([rar_idx, grp]))
        m = lgb.train(lgb_params, lgb.Dataset(X_tr.iloc[idx], label=y_tr.iloc[idx]), num_boost_round=ROUNDS)
        preds += m.predict(X_va)

    preds /= N_MODELS
    auc = roc_auc_score(y_va, preds)
    cv_aucs.append(auc)
    print(f"[LGB CV] Fold {fold} AUC: {auc:.4f}")

print(f"[LGB CV] Mean AUC: {np.mean(cv_aucs):.4f} ± {np.std(cv_aucs):.4f}")
# Out:
# [LGB CV] Fold 1 AUC: 0.8877
# [LGB CV] Fold 2 AUC: 0.9060
# [LGB CV] Fold 3 AUC: 0.8966
# [LGB CV] Fold 4 AUC: 0.8831
# [LGB CV] Fold 5 AUC: 0.8860
# [LGB CV] Mean AUC: 0.8919 ± 0.0084

# %%
# ┌───────────────────────────────────────────────────────────────┐
# Cell B3: Retrain full LightGBM ensemble on ALL data & submit
# └───────────────────────────────────────────────────────────────┘
import numpy as np
import joblib
import lightgbm as lgb

ROUNDS = 300
lgb_models = []
arr = y.values
maj_idx = np.where(arr == 0)[0]
rar_idx = np.where(arr == 1)[0]
splits = np.array_split(np.random.RandomState(SEED).permutation(maj_idx), N_MODELS)

for grp in splits:
    idx = np.sort(np.concatenate([rar_idx, grp]))
    m = lgb.train(lgb_params, lgb.Dataset(train_features.iloc[idx], label=y.iloc[idx]), num_boost_round=ROUNDS)
    lgb_models.append(m)

test_preds = np.mean([m.predict(test_features) for m in lgb_models], axis=0)
sub = submission_format.copy()
sub['coppaRisk'] = test_preds
sub.to_csv('lgb_majority_ensemble.csv', index=False)
print("✅ lgb_majority_ensemble.csv saved")
joblib.dump(lgb_models, 'lgb_majority_ensemble.pkl')
# Out:
# ✅ lgb_majority_ensemble.csv saved
# ['lgb_majority_ensemble.pkl']

# %% [markdown]
# # Xgboost

# %%
# ┌───────────────────────────────────────────────────────────────┐
# Cell A1: Tune XGBoost via Optuna + majority/minority hold-out
# └───────────────────────────────────────────────────────────────┘
import numpy as np
import optuna
import xgboost as xgb
from sklearn.metrics import roc_auc_score

N_MODELS = 9
SEED     = 42
ROUNDS   = 300  # n_estimators

def objective_xgb(trial):
    params = {
        'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
        'max_depth':          trial.suggest_int('max_depth', 3, 12),
        'min_child_weight':   trial.suggest_int('min_child_weight', 1, 10),
        'gamma':              trial.suggest_float('gamma', 0.0, 2.0),
        'subsample':          trial.suggest_float('subsample', 0.4, 1.0),
        'colsample_bytree':   trial.suggest_float('colsample_bytree', 0.4, 1.0),
        'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
        'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
        'objective':          'binary:logistic',
        'eval_metric':        'auc',
        'use_label_encoder':  False,
        'verbosity':          0,
        'seed':               SEED,
        'tree_method':        'hist'
    }

    # majority/minority hold-out on X_train→X_val
    preds = np.zeros(len(X_val), dtype=float)
    arr = y_train.values
    maj_idx = np.where(arr == 0)[0]
    rar_idx = np.where(arr == 1)[0]
    rng = np.random.RandomState(SEED)
    splits = np.array_split(rng.permutation(maj_idx), N_MODELS)

    for grp in splits:
        idx = np.sort(np.concatenate([rar_idx, grp]))
        X_sub, y_sub = X_train.iloc[idx], y_train.iloc[idx]
        model = xgb.XGBClassifier(**params, n_estimators=ROUNDS)
        model.fit(X_sub, y_sub)
        preds += model.predict_proba(X_val)[:,1]

    preds /= N_MODELS
    return roc_auc_score(y_val, preds)

study_xgb = optuna.create_study(direction='maximize')
study_xgb.optimize(objective_xgb, n_trials=200, timeout=3600)

best_xgb = study_xgb.best_trial.params
print("▶ Best XGB params:", best_xgb)
print(f"▶ Hold-out AUC: {study_xgb.best_value:.4f}")
# Out:
# [I 2025-04-28 08:48:16,788] A new study created in memory with name: no-name-004a48e4-caa6-49d5-aac7-56ee779795db
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:21,365] Trial 0 finished with value: 0.891087922683265 and parameters: {'learning_rate': 0.08485771845062871, 'max_depth': 4, 'min_child_weight': 6, 'gamma': 1.137573522662165, 'subsample': 0.6340960965264234, 'colsample_bytree': 0.6198424359241197, 'reg_alpha': 0.10474740926422153, 'reg_lambda': 3.0548537071359494e-08}. Best is trial 0 with value: 0.891087922683265.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:26,276] Trial 1 finished with value: 0.8912419628135715 and parameters: {'learning_rate': 0.01625829655938765, 'max_depth': 8, 'min_child_weight': 6, 'gamma': 0.3275376222751256, 'subsample': 0.9727573108543738, 'colsample_bytree': 0.6068892045771359, 'reg_alpha': 4.391384213844019, 'reg_lambda': 0.13408778195423468}. Best is trial 1 with value: 0.8912419628135715.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:30,556] Trial 2 finished with value: 0.8837111119985851 and parameters: {'learning_rate': 0.004456766805087227, 'max_depth': 3, 'min_child_weight': 1, 'gamma': 0.6773017167971911, 'subsample': 0.4465392976004736, 'colsample_bytree': 0.4073312907426399, 'reg_alpha': 0.19389873721659998, 'reg_lambda': 0.12386470853822285}. Best is trial 1 with value: 0.8912419628135715.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:36,039] Trial 3 finished with value: 0.8946222878952983 and parameters: {'learning_rate': 0.004775376390943463, 'max_depth': 10, 'min_child_weight': 5, 'gamma': 1.6625398303342716, 'subsample': 0.7743573515071526, 'colsample_bytree': 0.950184999753424, 'reg_alpha': 2.9043148221460706e-08, 'reg_lambda': 0.0011167882844927853}. Best is trial 3 with value: 0.8946222878952983.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:40,668] Trial 4 finished with value: 0.8904147102619253 and parameters: {'learning_rate': 0.06816230675033712, 'max_depth': 6, 'min_child_weight': 6, 'gamma': 1.4368122578467284, 'subsample': 0.40004797809005316, 'colsample_bytree': 0.7704692752106173, 'reg_alpha': 0.01218057705007055, 'reg_lambda': 4.539985867028322e-07}. Best is trial 3 with value: 0.8946222878952983.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:45,416] Trial 5 finished with value: 0.8962625300235624 and parameters: {'learning_rate': 0.025963527527524004, 'max_depth': 8, 'min_child_weight': 5, 'gamma': 1.379151822786633, 'subsample': 0.764129202082372, 'colsample_bytree': 0.7180162032042546, 'reg_alpha': 0.00012717759943898347, 'reg_lambda': 0.0014785180317436926}. Best is trial 5 with value: 0.8962625300235624.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:50,033] Trial 6 finished with value: 0.8868061775797442 and parameters: {'learning_rate': 0.0012630002953700262, 'max_depth': 4, 'min_child_weight': 3, 'gamma': 1.1473536887733986, 'subsample': 0.9717421611343733, 'colsample_bytree': 0.4377979322782047, 'reg_alpha': 5.308529048773866e-07, 'reg_lambda': 0.00020717495330995134}. Best is trial 5 with value: 0.8962625300235624.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:54,822] Trial 7 finished with value: 0.8982308205774794 and parameters: {'learning_rate': 0.00836796579969849, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.5595743730518397, 'subsample': 0.8045280844211931, 'colsample_bytree': 0.41953736852573237, 'reg_alpha': 6.517935770841754e-07, 'reg_lambda': 0.22711302696281035}. Best is trial 7 with value: 0.8982308205774794.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:48:59,748] Trial 8 finished with value: 0.897740174236503 and parameters: {'learning_rate': 0.01653945203005571, 'max_depth': 9, 'min_child_weight': 2, 'gamma': 1.9082651233288013, 'subsample': 0.4112207650509115, 'colsample_bytree': 0.6356219292884305, 'reg_alpha': 0.009044169550835767, 'reg_lambda': 0.02656898514532728}. Best is trial 7 with value: 0.8982308205774794.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:04,944] Trial 9 finished with value: 0.9021160549752111 and parameters: {'learning_rate': 0.02101372646622817, 'max_depth': 9, 'min_child_weight': 2, 'gamma': 1.8409337409010014, 'subsample': 0.9182848516518473, 'colsample_bytree': 0.44436045890026643, 'reg_alpha': 0.0036532612867296076, 'reg_lambda': 2.5724817562578675e-08}. Best is trial 9 with value: 0.9021160549752111.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:09,401] Trial 10 finished with value: 0.8965534947141415 and parameters: {'learning_rate': 0.03497353288919667, 'max_depth': 12, 'min_child_weight': 10, 'gamma': 1.927927996926986, 'subsample': 0.877188050592571, 'colsample_bytree': 0.5210922258432124, 'reg_alpha': 0.00010732529921031, 'reg_lambda': 3.925362303489881e-06}. Best is trial 9 with value: 0.9021160549752111.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:14,595] Trial 11 finished with value: 0.894767770240588 and parameters: {'learning_rate': 0.005938161256000145, 'max_depth': 6, 'min_child_weight': 3, 'gamma': 0.018318860606527654, 'subsample': 0.8540502084298436, 'colsample_bytree': 0.5098326824743177, 'reg_alpha': 5.416047853011719e-06, 'reg_lambda': 1.3902991565442437}. Best is trial 9 with value: 0.9021160549752111.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:19,800] Trial 12 finished with value: 0.9015284204040415 and parameters: {'learning_rate': 0.008765216435652687, 'max_depth': 6, 'min_child_weight': 1, 'gamma': 0.7974365073491925, 'subsample': 0.6307174491581398, 'colsample_bytree': 0.5056719594110719, 'reg_alpha': 1.2793870437625598e-08, 'reg_lambda': 4.422077082247517e-06}. Best is trial 9 with value: 0.9021160549752111.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:25,811] Trial 13 finished with value: 0.8913674769938214 and parameters: {'learning_rate': 0.0018527813448653892, 'max_depth': 11, 'min_child_weight': 3, 'gamma': 0.8182670687934926, 'subsample': 0.6329811403347202, 'colsample_bytree': 0.5274462809719371, 'reg_alpha': 0.0012674331679660119, 'reg_lambda': 1.0171188418046898e-08}. Best is trial 9 with value: 0.9021160549752111.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:30,891] Trial 14 finished with value: 0.8930932969722558 and parameters: {'learning_rate': 0.0028428659547473866, 'max_depth': 7, 'min_child_weight': 9, 'gamma': 0.9421140278630205, 'subsample': 0.5368338690998526, 'colsample_bytree': 0.927478526934752, 'reg_alpha': 1.9730033650493662e-08, 'reg_lambda': 7.017955137260974e-06}. Best is trial 9 with value: 0.9021160549752111.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:36,750] Trial 15 finished with value: 0.9030517061370729 and parameters: {'learning_rate': 0.012287017453556004, 'max_depth': 9, 'min_child_weight': 1, 'gamma': 0.4053377223274025, 'subsample': 0.6645187784912041, 'colsample_bytree': 0.49738131153671467, 'reg_alpha': 2.3159537521604012e-06, 'reg_lambda': 4.044813636435962e-07}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:42,382] Trial 16 finished with value: 0.891704083204491 and parameters: {'learning_rate': 0.03939003377259511, 'max_depth': 10, 'min_child_weight': 4, 'gamma': 0.2782913236850189, 'subsample': 0.701507826241583, 'colsample_bytree': 0.828975445770185, 'reg_alpha': 1.0765329564248429e-05, 'reg_lambda': 1.0904476122905911e-07}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:48,190] Trial 17 finished with value: 0.9000621865711238 and parameters: {'learning_rate': 0.014829744726861743, 'max_depth': 9, 'min_child_weight': 2, 'gamma': 0.43387064960850563, 'subsample': 0.5579839577073608, 'colsample_bytree': 0.5742873058507573, 'reg_alpha': 1.4822091915221917e-05, 'reg_lambda': 3.5835053584247603e-07}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:52,936] Trial 18 finished with value: 0.8959031030528471 and parameters: {'learning_rate': 0.024141112258815253, 'max_depth': 12, 'min_child_weight': 7, 'gamma': 1.6404504928942423, 'subsample': 0.8841164702372192, 'colsample_bytree': 0.686483134670375, 'reg_alpha': 0.001642749348226628, 'reg_lambda': 3.962707900741967e-05}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:49:58,355] Trial 19 finished with value: 0.8932102533674884 and parameters: {'learning_rate': 0.052812111752787876, 'max_depth': 10, 'min_child_weight': 8, 'gamma': 0.04327900374768556, 'subsample': 0.7034890489330268, 'colsample_bytree': 0.4828481488477891, 'reg_alpha': 3.831981728114975e-07, 'reg_lambda': 7.037962113077229e-07}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:02,926] Trial 20 finished with value: 0.8848863811409239 and parameters: {'learning_rate': 0.01158081684810666, 'max_depth': 9, 'min_child_weight': 2, 'gamma': 1.227300119854755, 'subsample': 0.5359690206483023, 'colsample_bytree': 0.461812145953976, 'reg_alpha': 4.7518034105109, 'reg_lambda': 4.2229561956533135e-08}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:08,359] Trial 21 finished with value: 0.902327147005631 and parameters: {'learning_rate': 0.008692699776495425, 'max_depth': 7, 'min_child_weight': 1, 'gamma': 0.8036888268043044, 'subsample': 0.6327970320535523, 'colsample_bytree': 0.5720388278937316, 'reg_alpha': 9.179518664037439e-08, 'reg_lambda': 5.239624824993393e-06}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:13,815] Trial 22 finished with value: 0.9025952909361646 and parameters: {'learning_rate': 0.006777779815278674, 'max_depth': 7, 'min_child_weight': 1, 'gamma': 0.5645552903126605, 'subsample': 0.5829656372975379, 'colsample_bytree': 0.5683883794574194, 'reg_alpha': 1.376433260577158e-07, 'reg_lambda': 3.964125694774112e-05}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:19,161] Trial 23 finished with value: 0.9022700951055175 and parameters: {'learning_rate': 0.007081489965311654, 'max_depth': 7, 'min_child_weight': 1, 'gamma': 0.604200383007574, 'subsample': 0.5910649713229233, 'colsample_bytree': 0.5674277626568563, 'reg_alpha': 1.2269535832858941e-07, 'reg_lambda': 0.0001121940183436895}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:24,521] Trial 24 finished with value: 0.8955722020321887 and parameters: {'learning_rate': 0.0031627444063142785, 'max_depth': 7, 'min_child_weight': 3, 'gamma': 0.20965369145860457, 'subsample': 0.4847168059842584, 'colsample_bytree': 0.6665058033077763, 'reg_alpha': 2.532376674524546e-06, 'reg_lambda': 2.0378765579666963e-05}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:30,016] Trial 25 finished with value: 0.8974377991659013 and parameters: {'learning_rate': 0.01071106212406492, 'max_depth': 8, 'min_child_weight': 4, 'gamma': 0.5215543465055172, 'subsample': 0.6674690018923349, 'colsample_bytree': 0.7457111568930304, 'reg_alpha': 9.904549012726297e-08, 'reg_lambda': 0.001986107094272811}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:35,103] Trial 26 finished with value: 0.8984818489379789 and parameters: {'learning_rate': 0.0027826903119539587, 'max_depth': 6, 'min_child_weight': 1, 'gamma': 0.7965649691467415, 'subsample': 0.7265471790375247, 'colsample_bytree': 0.5702449363172791, 'reg_alpha': 2.068135740644551e-06, 'reg_lambda': 2.120110845596468e-06}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:40,003] Trial 27 finished with value: 0.8975747237261738 and parameters: {'learning_rate': 0.0048690198851964635, 'max_depth': 5, 'min_child_weight': 2, 'gamma': 0.41053108206697875, 'subsample': 0.5888994001377484, 'colsample_bytree': 0.5575469176623542, 'reg_alpha': 3.5095318541979376e-05, 'reg_lambda': 3.245495048327109e-05}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:45,411] Trial 28 finished with value: 0.8968958061148228 and parameters: {'learning_rate': 0.011956654118851164, 'max_depth': 8, 'min_child_weight': 4, 'gamma': 1.0023785297402799, 'subsample': 0.667936583947171, 'colsample_bytree': 0.8137360089358059, 'reg_alpha': 9.205457812799262e-08, 'reg_lambda': 9.62261042574217e-07}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:50,500] Trial 29 finished with value: 0.8999309672008626 and parameters: {'learning_rate': 0.006537688826377185, 'max_depth': 5, 'min_child_weight': 1, 'gamma': 0.16414055248108006, 'subsample': 0.49488433920391106, 'colsample_bytree': 0.6264256434775319, 'reg_alpha': 1.1318336046973853e-06, 'reg_lambda': 2.038771611439614e-07}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:50:55,377] Trial 30 finished with value: 0.8888172570587463 and parameters: {'learning_rate': 0.09732639489452874, 'max_depth': 7, 'min_child_weight': 2, 'gamma': 0.6990943005161214, 'subsample': 0.6023733773834368, 'colsample_bytree': 0.645858596206007, 'reg_alpha': 1.6063703874134633e-07, 'reg_lambda': 0.004580114905350989}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 08:51:00,746] Trial 31 finished with value: 0.9026865739763463 and parameters: {'learning_rate': 0.007263112950943283, 'max_depth': 7, 'min_child_weight': 1, 'gamma': 0.5960217037760226, 'subsample': 0.5887233473323346, 'colsample_bytree': 0.5934835737818743, 'reg_alpha': 7.889929961300454e-08, 'reg_lambda': 0.00012269664982906983}. Best is trial 15 with value: 0.9030517061370729.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# ...
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:02:49,805] Trial 189 finished with value: 0.904038704009037 and parameters: {'learning_rate': 0.07729858693822728, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.4356464132261364, 'subsample': 0.9466375088454854, 'colsample_bytree': 0.4496388600462067, 'reg_alpha': 0.00014559792743322448, 'reg_lambda': 2.0542741269829537e-06}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:02:54,249] Trial 190 finished with value: 0.9004387291118731 and parameters: {'learning_rate': 0.09120615877949366, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.4967090646142034, 'subsample': 0.9260387998171097, 'colsample_bytree': 0.8709220415653649, 'reg_alpha': 9.626062681827861e-05, 'reg_lambda': 0.00044673430990417715}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:02:59,070] Trial 191 finished with value: 0.9046948008603426 and parameters: {'learning_rate': 0.09420610883084403, 'max_depth': 10, 'min_child_weight': 1, 'gamma': 1.5383154111912325, 'subsample': 0.9715847920781449, 'colsample_bytree': 0.42311075320541686, 'reg_alpha': 0.0003711128358664266, 'reg_lambda': 5.600999037885345e-06}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:03:03,313] Trial 192 finished with value: 0.9046548645302631 and parameters: {'learning_rate': 0.09978707186440425, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.608041722500772, 'subsample': 0.9714372570513604, 'colsample_bytree': 0.4215325653952255, 'reg_alpha': 5.621257545635489e-05, 'reg_lambda': 1.131617994573053e-05}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:03:07,634] Trial 193 finished with value: 0.9058643648126702 and parameters: {'learning_rate': 0.0850807163398589, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.2710017476817024, 'subsample': 0.9573053504572091, 'colsample_bytree': 0.42980352712854253, 'reg_alpha': 5.963183450764636e-05, 'reg_lambda': 3.956381981575734e-06}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:03:11,883] Trial 194 finished with value: 0.9040272936290142 and parameters: {'learning_rate': 0.0855824763214126, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.308113157329277, 'subsample': 0.9531382116066799, 'colsample_bytree': 0.4115197028469863, 'reg_alpha': 5.199532499104044e-05, 'reg_lambda': 3.3165756748750018e-06}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:03:16,233] Trial 195 finished with value: 0.9037876756485375 and parameters: {'learning_rate': 0.07509955826116628, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.2600085330561923, 'subsample': 0.9397622768994567, 'colsample_bytree': 0.43530726741914877, 'reg_alpha': 0.00011810165279975222, 'reg_lambda': 2.0686267970995904e-06}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:03:20,579] Trial 196 finished with value: 0.9011804038133491 and parameters: {'learning_rate': 0.08382073177895007, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.3888795354099863, 'subsample': 0.7934547062893273, 'colsample_bytree': 0.4008137754425883, 'reg_alpha': 0.00020537441957277304, 'reg_lambda': 4.552073138418774e-06}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:03:24,907] Trial 197 finished with value: 0.9047404423804335 and parameters: {'learning_rate': 0.07140828615073774, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.3443936988416776, 'subsample': 0.9588251352747829, 'colsample_bytree': 0.4450633917685134, 'reg_alpha': 3.443365176112922e-05, 'reg_lambda': 7.2940654457194495e-06}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:03:29,066] Trial 198 finished with value: 0.9009008495027927 and parameters: {'learning_rate': 0.09044611893019257, 'max_depth': 11, 'min_child_weight': 4, 'gamma': 1.2766346056138953, 'subsample': 0.9647266953394208, 'colsample_bytree': 0.4182681724317327, 'reg_alpha': 3.9367741394226255e-05, 'reg_lambda': 4.228588428773272e-06}. Best is trial 133 with value: 0.9062523177334421.
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:15: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate':      trial.suggest_loguniform('learning_rate', 1e-3, 1e-1),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:21: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha':          trial.suggest_loguniform('reg_alpha', 1e-8, 10.0),
# C:\Users\PETRA LEKA\AppData\Local\Temp\ipykernel_22472\3621266009.py:22: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda':         trial.suggest_loguniform('reg_lambda', 1e-8, 10.0),
# [I 2025-04-28 09:03:33,506] Trial 199 finished with value: 0.9015797671141437 and parameters: {'learning_rate': 0.0771264153445145, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.567813098448699, 'subsample': 0.6878674261572344, 'colsample_bytree': 0.43159366264284016, 'reg_alpha': 1.783565583613109e-05, 'reg_lambda': 7.781583257652e-06}. Best is trial 133 with value: 0.9062523177334421.
# ▶ Best XGB params: {'learning_rate': 0.08881182046802887, 'max_depth': 11, 'min_child_weight': 1, 'gamma': 1.5132941267619924, 'subsample': 0.9809952824406312, 'colsample_bytree': 0.4242910594890692, 'reg_alpha': 0.0405420760888111, 'reg_lambda': 3.6925176750154237e-06}
# ▶ Hold-out AUC: 0.9063

# %%
# ┌───────────────────────────────────────────────────────────────┐
# Cell A2: 5-Fold Stratified CV of XGBoost majority/minority
# └───────────────────────────────────────────────────────────────┘
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import xgboost as xgb

ROUNDS = 300
xgb_params = dict(best_xgb)  # copy best_xgb
xgb_params.update({
    'objective':'binary:logistic','eval_metric':'auc',
    'use_label_encoder':False,'verbosity':0,'seed':SEED,'tree_method':'hist'
})

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
cv_aucs = []

for fold, (tr, va) in enumerate(kf.split(train_features, y), 1):
    preds = np.zeros(len(va), dtype=float)
    X_tr, X_va = train_features.iloc[tr], train_features.iloc[va]
    y_tr, y_va = y.iloc[tr], y.iloc[va]

    arr = y_tr.values
    maj_idx = np.where(arr == 0)[0]
    rar_idx = np.where(arr == 1)[0]
    splits = np.array_split(np.random.RandomState(SEED).permutation(maj_idx), N_MODELS)

    for grp in splits:
        idx = np.sort(np.concatenate([rar_idx, grp]))
        m = xgb.XGBClassifier(**xgb_params, n_estimators=ROUNDS)
        m.fit(X_tr.iloc[idx], y_tr.iloc[idx])
        preds += m.predict_proba(X_va)[:,1]

    preds /= N_MODELS
    auc = roc_auc_score(y_va, preds)
    cv_aucs.append(auc)
    print(f"[XGB CV] Fold {fold} AUC: {auc:.4f}")

print(f"[XGB CV] Mean AUC: {np.mean(cv_aucs):.4f} ± {np.std(cv_aucs):.4f}")
# Out:
# [XGB CV] Fold 1 AUC: 0.8865
# [XGB CV] Fold 2 AUC: 0.9066
# [XGB CV] Fold 3 AUC: 0.8958
# [XGB CV] Fold 4 AUC: 0.8877
# [XGB CV] Fold 5 AUC: 0.8839
# [XGB CV] Mean AUC: 0.8921 ± 0.0083

# %%
# ┌───────────────────────────────────────────────────────────────┐
# Cell A3: Retrain full XGBoost ensemble on ALL data & submit
# └───────────────────────────────────────────────────────────────┘
import numpy as np
import joblib
import xgboost as xgb

# rebuild XGBoost ensemble on full train_features+y
xgb_models = []
arr = y.values
maj_idx = np.where(arr == 0)[0]
rar_idx = np.where(arr == 1)[0]
splits = np.array_split(np.random.RandomState(SEED).permutation(maj_idx), N_MODELS)

for grp in splits:
    idx = np.sort(np.concatenate([rar_idx, grp]))
    m = xgb.XGBClassifier(**xgb_params, n_estimators=ROUNDS)
    m.fit(train_features.iloc[idx], y.iloc[idx])
    xgb_models.append(m)

# predict test
test_preds = np.mean([m.predict_proba(test_features)[:,1] for m in xgb_models], axis=0)
sub = submission_format.copy()
sub['coppaRisk'] = test_preds
sub.to_csv('xgb_majority_ensemble.csv', index=False)
print("✅ xgb_majority_ensemble.csv saved")
joblib.dump(xgb_models, 'xgb_majority_ensemble.pkl')
# Out:
# ✅ xgb_majority_ensemble.csv saved
# ['xgb_majority_ensemble.pkl']

# %% [markdown]
# # Cat + Lgb + Xgb

# %%
# ┌───────────────────────────────────────────────────────────────┐
# Cell C: Blend all three 9-model ensembles & CV + Submission
# └───────────────────────────────────────────────────────────────┘
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import joblib
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier

# load your 9-model ensembles
cb_models  = joblib.load('catboost_majority_ensemble.pkl')
xgb_models = joblib.load('xgb_majority_ensemble.pkl')
lgb_models = joblib.load('lgb_majority_ensemble.pkl')
ALL_MODELS = cb_models + xgb_models + lgb_models

# 1) 5-fold Stratified CV on train_features,y
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
cv_aucs = []
for fold, (tr, va) in enumerate(kf.split(train_features, y), 1):
    preds = np.zeros(len(va), dtype=float)
    X_va = train_features.iloc[va]
    y_va = y.iloc[va]
    for m in ALL_MODELS:
        if isinstance(m, lgb.Booster):
            preds += m.predict(X_va)
        else:
            preds += m.predict_proba(X_va)[:,1]
    preds /= len(ALL_MODELS)
    auc = roc_auc_score(y_va, preds)
    cv_aucs.append(auc)
    print(f"[Blend CV] Fold {fold} AUC: {auc:.4f}")

print(f"[Blend CV] Mean AUC: {np.mean(cv_aucs):.4f} ± {np.std(cv_aucs):.4f}")

# 2) Full test prediction & submission
test_preds = np.zeros(len(test_features), dtype=float)
for m in ALL_MODELS:
    if isinstance(m, lgb.Booster):
        test_preds += m.predict(test_features)
    else:
        test_preds += m.predict_proba(test_features)[:,1]
test_preds /= len(ALL_MODELS)

sub = submission_format.copy()
sub['coppaRisk'] = test_preds
sub.to_csv('full_27_model_ensemble.csv', index=False)
print("✅ full_27_model_ensemble.csv saved")
# Out:
# [Blend CV] Fold 1 AUC: 0.9524
# [Blend CV] Fold 2 AUC: 0.9610
# [Blend CV] Fold 3 AUC: 0.9556
# [Blend CV] Fold 4 AUC: 0.9496
# [Blend CV] Fold 5 AUC: 0.9486
# [Blend CV] Mean AUC: 0.9534 ± 0.0045
# ✅ full_27_model_ensemble.csv saved
